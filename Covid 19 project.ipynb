# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv('Madedata1.csv')

# %%
df['Infected'].value_counts()
# Out:
# 1    1260
# 0    1239
# Name: Infected, dtype: int64

# %%
df.head()
# Out:
#               Country  Age       Gender  fever  Bodypain  Runny_nose  \
# 0               China   10         Male    102         1           0
# 1               Italy   20         Male    103         1           1
# 2                Iran   55  Transgender     99         0           0
# 3  Republic of Korean   37       Female    100         0           1
# 4              France   45         Male    101         1           1
#
#    Difficulty_in_breathing  Nasal_congestion  Sore_throat  Severity  \
# 0                        0                 0            1      Mild
# 1                        0                 0            0  Moderate
# 2                        0                 1            1    Severe
# 3                        1                 0            0      Mild
# 4                        1                 1            0  Moderate
#
#   Contact_with_covid_patient  Infected
# 0                         No         0
# 1                  Not known         1
# 2                         No         0
# 3                        Yes         1
# 4                        Yes         1

# %%
Country=df['Country']
Age=df['Age']
Fever=df['fever']
Bodypain=df['Bodypain']
diff=df['Difficulty_in_breathing']
Sore_throat=df['Sore_throat']

# %%
x=df[['fever','Bodypain','Difficulty_in_breathing','Sore_throat']].values
y=df['Infected'].values

# %%
d={'Country':Country,'Age':Age,'Fever':Fever,'Bodypain':Bodypain,'Difficulty_in_breathing':diff,'Sore_throat':Sore_throat}

# %%
pd.DataFrame(d)
# Out:
#                  Country  Age  Fever  Bodypain  Difficulty_in_breathing  \
# 0                  China   10    102         1                        0
# 1                  Italy   20    103         1                        0
# 2                   Iran   55     99         0                        0
# 3     Republic of Korean   37    100         0                        1
# 4                 France   45    101         1                        1
# 5                  Spain   45     99         1                        0
# 6                Germany   24     98         0                        0
# 7                    UAE   37     99         0                        1
# 8                 Russia   40    101         0                        1
# 9                 Canada   37    100         0                        0
# 10                 China   35    101         1                        1
# 11           Netherlands   60    103         1                        1
# 12                Mexico   30     98         0                        0
# 13              Pakistan   35    102         0                        1
# 14                 Chile   37    100         0                        0
# 15                Sweden   35    104         1                        1
# 16                  Peru   18     99         1                        0
# 17               Ireland   39    100         1                        1
# 18             Singapore   55    102         1                        1
# 19                Turkey   55    103         1                        1
# 20                Russia   35    101         1                        0
# 21                France   35    100         0                        1
# 22                  Iran   37     99         0                        0
# 23              Pakistan   24    101         1                        0
# 24                 India   16     98         0                        0
# 25                Sweden   18    101         1                        1
# 26             Australia   24    104         1                        1
# 27              Malaysia   45    101         1                        0
# 28             Argentina   55    102         0                        0
# 29                Kuwait   73     98         0                        0
# ...                  ...  ...    ...       ...                      ...
# 2469              Sweden   65     98         1                        0
# 2470                Fiji   70    101         1                        1
# 2471              Bhutan   18    100         1                        0
# 2472           Greenland   37     99         0                        0
# 2473             Hungary   39    100         1                        0
# 2474            Pakistan   35    103         1                        1
# 2475            Mongolia   18     99         1                        0
# 2476             Vietnam   70    103         1                        1
# 2477               China   30     98         0                        0
# 2478              Serbia   35    102         0                        1
# 2479            Barbados   35    104         1                        1
# 2480            Bulgaria   18     99         1                        0
# 2481             Vietnam   39    100         1                        1
# 2482              France   55    102         1                        1
# 2483               Malta   40     99         0                        1
# 2484              Taiwan   65    103         1                        1
# 2485           Mauritius   35    101         1                        0
# 2486               Congo   35    100         0                        1
# 2487             Vietnam   37     99         0                        0
# 2488              Zambia   24    101         1                        0
# 2489             Hungary   16     98         0                        0
# 2490               Haiti   37    100         0                        1
# 2491             Liberia   45    101         1                        1
# 2492               Nepal   45     99         1                        0
# 2493                Togo   55    102         0                        0
# 2494             Myanmar   73     98         0                        0
# 2495            Cambodia   35    104         1                        1
# 2496             Finland   18     99         1                        0
# 2497             Morocco   39    100         1                        1
# 2498               Japan   55    102         1                        1
#
#       Sore_throat
# 0               1
# 1               0
# 2               1
# 3               0
# 4               0
# 5               1
# 6               1
# 7               1
# 8               0
# 9               0
# 10              1
# 11              1
# 12              0
# 13              1
# 14              0
# 15              0
# 16              1
# 17              0
# 18              0
# 19              1
# 20              1
# 21              0
# 22              0
# 23              1
# 24              0
# 25              0
# 26              1
# 27              0
# 28              1
# 29              0
# ...           ...
# 2469            1
# 2470            0
# 2471            1
# 2472            1
# 2473            1
# 2474            0
# 2475            1
# 2476            1
# 2477            0
# 2478            1
# 2479            0
# 2480            1
# 2481            0
# 2482            0
# 2483            0
# 2484            1
# 2485            1
# 2486            0
# 2487            0
# 2488            1
# 2489            0
# 2490            0
# 2491            0
# 2492            1
# 2493            1
# 2494            0
# 2495            0
# 2496            1
# 2497            0
# 2498            0
#
# [2499 rows x 6 columns]

# %%
df.info()#give info about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2499 entries, 0 to 2498
# Data columns (total 12 columns):
# Country                       2499 non-null object
# Age                           2499 non-null int64
# Gender                        2499 non-null object
# fever                         2499 non-null int64
# Bodypain                      2499 non-null int64
# Runny_nose                    2499 non-null int64
# Difficulty_in_breathing       2499 non-null int64
# Nasal_congestion              2499 non-null int64
# Sore_throat                   2499 non-null int64
# Severity                      2499 non-null object
# Contact_with_covid_patient    2499 non-null object
# Infected                      2499 non-null int64
# dtypes: int64(8), object(4)
# memory usage: 234.4+ KB

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
d=pd.DataFrame(x_train)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
f=int(input("Enter your fever in degree: "))
b=int(input("Do you have body pain? if yes enter 1 else 0: "))
d=int(input("Do you have difficulty in breathing? if yes enter 1 else 0: "))
s=int(input("Do you have sore throat? if yes enter 1 else 0: "))
# Out:
# Enter your fever in degree: 102
# Do you have body pain? if yes enter 1 else 0: 1
# Do you have difficulty in breathing? if yes enter 1 else 0: 1
# Do you have sore throat? if yes enter 1 else 0: 0

# %%
inputfeature=[]
inputfeature.append(f)
inputfeature.append(b)
inputfeature.append(d)
inputfeature.append(s)

# %%
inputfeature
# Out:
# [102, 1, 1, 0]

# %%
Infectedprob=clf.predict([inputfeature])
Infectedprob
# Out:
# array([1], dtype=int64)

# %%
prob=clf.predict_proba([inputfeature])[0][1]

# %%
print('Probability of having corona virus is: ',prob)
# Out:
# Probability of having corona virus is:  0.9388521941375471
